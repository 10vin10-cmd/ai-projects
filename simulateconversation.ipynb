# %%
import litellm
from textwrap import dedent
from dotenv import load_dotenv

load_dotenv()

print(f"Libraries and environment variables loaded sucessfuly")
# Out:
# Libraries and environment variables loaded sucessfuly

# %%
def get_completion(prompt, model, max_tokens=20):
    print("--- Getting completion from LiteLLM---")

    response = litellm.completion(
        model=model,
        messages=[
            {
                "role":"user",
                "content":"You are a helpful travel assistant"
            },
            {
                "role":"user",
                "content":prompt
            }
        ],
        max_tokens=max_tokens
    )

    return response

def analyze_cost(response):
    if not response:
        print("cannont analyze cost of a failed API")
        return
        
    raw_model_name = response.model

    if "/" in raw_model_name:
        raw_model_name = raw_model_name.split("/")[-1]
        
    model_used = None

    for model in MODEL_PRICING.keys():
        if raw_model_name.startswith(model):
            model_used = model
            break
    price_info = MODEL_PRICING[model_used]

    if not price_info:
        print(f"WARNING: Pricing for model '{model_used} not found")
        return
    usage_data = response.usage
    input_tokens = usage_data.prompt_tokens
    output_tokens = usage_data.completion_tokens

    price_per_input = price_info["input_per_1m"] / 1_000_000
    price_per_output = price_info["output_per_1m"] / 1_000_000

    input_cost = input_tokens * price_per_input
    output_cost = output_tokens * price_per_output
    total_cost = input_cost + output_cost

    print(f"\n-----------Cost Break-down for model: {model_used}-----")
    print(f"Input Tokens: \t{input_tokens} Cost: {input_cost:.8f}")
    print(f"output Tokens: \t{output_tokens} Cost: {output_cost:.8f}")
    print(f"Total Cost of API : \t{total_cost:.8f}")
        

#user_prompt = "what is the capital of France, and what is it famous for?"


#response = get_completion(
#            user_prompt,
#            model=MODEL_NAME
#        )

# %%
MODEL_PRICING = {
    "gpt-4o-mini": {
        "input_per_1m": 0.15,
        "output_per_1m": 0.60
    }
}

MODEL_NAME = "openai/gpt-4o-mini"

price_info = MODEL_PRICING[MODEL_NAME.split("/")[-1]]
PRICE_PER_INPUT_TOKEN = price_info["input_per_1m"] / 1_000_000
PRICE_PER_OUTPUT_TOKEN = price_info["output_per_1m"] / 1_000_000

def simulate_conversation():
    conversation_history = [
        {
            "role":"user",
            "content":dedent(""" 
            You are a senior software engineer well versed in Pythiiin.
            Your answers are comprehensive and intuitive to follow.
            """)
        }
    ]

    conversation_rounds = [
        "What is Python and what makes it popular for development?",
        "How do I createa virtual environment in that language?",
        "What are the top 5 most important libiriaries for beginners?",
        "Can you show me a simple example of using one of those libraries"
    ]

    total_cumulative_cost = 0

    for round_num, user_message in enumerate(conversation_rounds, start=1):
        print(f"--- Round {round_num} ----")
        print(f"USer Messsage:  {user_message}")

        conversation_history.append({
            "role":"user",
            "content":user_message
        })

        response = litellm.completion(
            model=MODEL_NAME,
            messages=conversation_history,
            max_tokens = 50
        )

        assistant_message = response.choices[0].message.content
        print(f"Assistant : {assistant_message}")

        conversation_history.append({
            "role":"assistant",
            "content":assistant_message
        })

        print()
        print("+"*50)
        analyze_cost(response)
        print("+"*50)   
    print("\n======SUMMARY=======")
    print(f"Total Cumulative Cost:Cost: {total_cumulative_cost:.8f}")
    print(f"Average Cost Per Round:Cost: {total_cumulative_cost/len(conversation_rounds):.8f}")
    print(f"Final Conversation Length:Cost: {len(conversation_history):.8f}")
simulate_conversation()
# Out:
# --- Round 1 ----
# USer Messsage:  What is Python and what makes it popular for development?
# Assistant : Python is a high-level, interpreted programming language known for its emphasis on readability, simplicity, and ease of use. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including procedural, object
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# -----------Cost Break-down for model: gpt-4o-mini-----
# Input Tokens: 	46 Cost: 0.00000690
# output Tokens: 	50 Cost: 0.00003000
# Total Cost of API : 	0.00003690
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# --- Round 2 ----
# USer Messsage:  How do I createa virtual environment in that language?
# Assistant : Creating a virtual environment in Python is a great way to manage dependencies and isolate project environments. Here's a step-by-step guide on how to create and use a virtual environment:
#
# ### Step 1: Install Python
#
# Make sure you have Python installed on your
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# -----------Cost Break-down for model: gpt-4o-mini-----
# Input Tokens: 	115 Cost: 0.00001725
# output Tokens: 	50 Cost: 0.00003000
# Total Cost of API : 	0.00004725
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# --- Round 3 ----
# USer Messsage:  What are the top 5 most important libiriaries for beginners?
# Assistant : For beginners in Python, there are several essential libraries that can significantly enhance your development experience and help you accomplish various tasks efficiently. Here are the top five libraries that are highly recommended for beginners:
#
# 1. **NumPy**:
#    - **Purpose**
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# -----------Cost Break-down for model: gpt-4o-mini-----
# Input Tokens: 	187 Cost: 0.00002805
# output Tokens: 	50 Cost: 0.00003000
# Total Cost of API : 	0.00005805
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# --- Round 4 ----
# USer Messsage:  Can you show me a simple example of using one of those libraries
# Assistant : Sure! Let's use **NumPy**, a powerful library for numerical computing in Python. Below is a simple example that demonstrates how to create an array, perform some basic operations, and use NumPy functions.
#
# ### Example: Basic Operations with NumPy
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# -----------Cost Break-down for model: gpt-4o-mini-----
# Input Tokens: 	258 Cost: 0.00003870
# output Tokens: 	50 Cost: 0.00003000
# Total Cost of API : 	0.00006870
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ======SUMMARY=======
# Total Cumulative Cost:Cost: 0.00000000
# Average Cost Per Round:Cost: 0.00000000
# Final Conversation Length:Cost: 9.00000000
